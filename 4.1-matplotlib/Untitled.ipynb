# %%
# matplotlib
'''
    支持超过100种 可视化的效果
    
    matplotlib库 受到matlab的启发
    
    matplotlib.pyplot  调用这个 就可以使用所有的可视化方式
'''
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb#seaborn另一个简写是sns

# %matplotlib inline

# %%
plt.plot([3,1,4,5,2])#只传一个一维的 被当做y轴 x轴是索引
plt.ylabel('grade')

# plt.savefig('test',dpi=600)#默认存成一个PNG文件
#dpi是在每一寸空间中 英寸 包含的点的数量
# Out:
# Text(0,0.5,'grade')

# %%
plt.plot([0,2,4,6,8],[3,1,4,5,2])#有两个参数时 第一个是x第二个是y
plt.ylabel('grade')
# plt.axis([-1,10,0,6])
# Out:
# Text(0,0.5,'grade')
